# %%
import numpy as np
A = np.random.randn(4,3)
B = np.sum(A, axis = 1, keepdims = True)
B.shape
A, 'HIII', B
# Out:
# (array([[ 0.65562872,  1.19200834, -0.26337768],
#         [ 1.49240943, -0.01363313, -0.73150288],
#         [-1.81764939,  1.3048793 ,  0.5363881 ],
#         [-0.89534678, -2.09031308, -0.5314966 ]]),
#  'HIII',
#  array([[ 1.58425938],
#         [ 0.74727342],
#         [ 0.02361802],
#         [-3.51715646]]))
