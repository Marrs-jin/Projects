# %%
import pandas as pd
import numpy as np
import pylab as pl
import glob
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pl.style.use("https://raw.githubusercontent.com/fedhere/MLTSA_FBianco/master/fbb.mplstyle")

# %% [markdown]
# # data ingestion

# %%
# download kaggle economic data
#https://www.kaggle.com/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/data#a.us.txt

# %%
#!pip install kaggle

# %%
from google.colab import drive

drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cd gdrive/My\ Drive/
# Out:
# [Errno 2] No such file or directory: 'gdrive/My Drive/'
# /content/gdrive/My Drive

# %%
ls kaggle.json
# Out:
# kaggle.json

# %%
# !chmod 600 kaggle.json

# %%
import json
import os
envs = json.load(open("kaggle.json", "r"))
os.environ["KAGGLE_USERNAME"] = envs['username']
os.environ["KAGGLE_KEY"] = envs['key']

# %%
os.environ
# Out:
# environ({'ENV': '/root/.bashrc', 'GCS_READ_CACHE_BLOCK_SIZE_MB': '16', 'CLOUDSDK_CONFIG': '/content/.config', 'CUDA_VERSION': '10.1.243', 'PATH': '/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin:/opt/bin', 'HOME': '/root', 'LD_LIBRARY_PATH': '/usr/local/nvidia/lib:/usr/local/nvidia/lib64', 'LANG': 'en_US.UTF-8', 'SHELL': '/bin/bash', 'LIBRARY_PATH': '/usr/local/cuda/lib64/stubs', 'CUDA_PKG_VERSION': '10-1=10.1.243-1', 'SHLVL': '1', 'GCE_METADATA_TIMEOUT': '0', 'NCCL_VERSION': '2.4.8', 'NVIDIA_VISIBLE_DEVICES': 'all', 'TF_FORCE_GPU_ALLOW_GROWTH': 'true', 'DEBIAN_FRONTEND': 'noninteractive', 'CUDNN_VERSION': '7.6.5.32', 'LAST_FORCED_REBUILD': '20200204', 'JPY_PARENT_PID': '18', 'PYTHONPATH': '/env/python', 'DATALAB_SETTINGS_OVERRIDES': '{"kernelManagerProxyPort":6000,"kernelManagerProxyHost":"172.28.0.3","jupyterArgs":["--ip=\\"172.28.0.2\\""]}', 'NO_GCE_CHECK': 'True', 'GLIBCXX_FORCE_NEW': '1', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', '_': '/tools/node/bin/node', 'LD_PRELOAD': '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4', 'NVIDIA_REQUIRE_CUDA': 'cuda>=10.1 brand=tesla,driver>=384,driver<385 brand=tesla,driver>=396,driver<397 brand=tesla,driver>=410,driver<411', 'OLDPWD': '/', 'HOSTNAME': '2dc9bad45868', 'COLAB_GPU': '0', 'PWD': '/', 'GLIBCPP_FORCE_NEW': '1', 'PYTHONWARNINGS': 'ignore:::pip._internal.cli.base_command', 'TBE_CREDS_ADDR': '172.28.0.1:8008', 'TERM': 'xterm-color', 'CLICOLOR': '1', 'PAGER': 'cat', 'GIT_PAGER': 'cat', 'MPLBACKEND': 'module://ipykernel.pylab.backend_inline', 'KAGGLE_USERNAME': 'adammarrs', 'KAGGLE_KEY': 'ee0e1fb208ee00dd524d3d808e58afe4'})

# %%
#check that it worked by listing the kaggle datasets
# !kaggle datasets
# Out:
# usage: kaggle datasets [-h]
#                        {list,files,download,create,version,init,metadata,status}
#                        ...
# kaggle datasets: error: too few arguments

# %%
# !kaggle datasets download borismarjanovic/price-volume-data-for-all-us-stocks-etfs
# Out:
# price-volume-data-for-all-us-stocks-etfs.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !ls
# Out:
#  13-23-05.mp4
# '1 cm Graph.JPG'
# '1st half of Soph-Junior Questions.docx.gdoc'
#  20161017_STEPYU9.docx
#  20161017_STEPYU9.docx.gdoc
#  20170110_165644.jpg
# '2017-05-16 Transcript_INTL Evaluation_Marrs, Adam 113094771.doc'
#  20190407_205955.jpg
#  20190407_210008.jpg
#  20190407_210014.jpg
# '20191130_141319[1] (1).mp4'
# '20191130_141319[1].mp4'
# '2 25-uggs.gdoc'
# '2 cm Graph.JPG'
# '3 cm Graph.JPG'
#  ニナ　アダム　アンバー　（3）.docx
#  ニナ　アダム　アンバー　（3）.docx.gdoc
# '45 Degree Collision.trk'
# '45 Degree Stick.trk'
# '4 Cm Graph.JPG'
# '90 Degree Collision.trk'
# '90 Degree Stick.trk'
#  aas_application.pdf
#  AAsecretstratgg.docx.gdoc
#  Abstract.gdoc
#  Accomplishments.gdoc
# 'ACT 201604 Form 73E-www.crackact.com.pdf'
# 'ACT 201612 Form 74H-www.crackact.com.pdf'
# 'ACT 201706 Form 74C-www.crackact.com.pdf'
# 'Adam Marrs AP Lit Block 2'
#  AdamMarrsASTR5900Outline.gdoc
#  ADAMPLAN.docx
#  adjustG.png
#  alsdhfo.jpg
# 'Analytical Essay 2.gdoc'
# '◆Arrival Informaiton Form(Excel).xlsx'
# '◆Arrival Informaiton Form(Excel).xlsx.gsheet'
# 'Birth and Death.gdoc'
# 'Boarding Pass - Check-in | Spirit Airlines.pdf'
#  Book1.xlsx
#  Boss.gdoc
# 'Braden Nrg-time.jpg'
# 'Car totaled.gdoc'
# 'CavendishFinalDraft (1).docx1.docx.docx.gdoc'
#  CavendishFinalDraft.docx
# 'CavendishFinalDraft.docx (1).docx'
#  CavendishFinalDraft.docx1.docx.docx
#  CavendishFinalDraft.docx1.docx.docx.gdoc
# 'CavendishFinalDraft.docx (1).docx.gdoc'
#  CavendishFinalDraft.docx.gdoc
# 'Cavendish Rough Draft.gdoc'
# 'Cavendish Write Up (1).docx.gdoc'
# 'Cavendish Write Up (2).docx.gdoc'
# 'Cavendish Write Up.docx'
# 'Cavendish Write Up.docx.gdoc'
# 'cd_15_minute_talk(5).pdf'
#  Chapter10exercises.docx
#  Chapter10exercises.docx.gdoc
# 'Chapter 11 Exercises.gdoc'
# 'Chapter 9 Exercises.gdoc'
#  Characters.gdoc
#  charguide.png
# 'Chicago Trip.gdoc'
#  Circuits.gslides
# 'CityU Student Residence Application SU18.pdf'
# 'Coding Records.gdoc'
# 'Colab Notebooks'
#  Colleges.gdoc
# 'College Stuff Fall 2017.gdoc'
# 'Conversation Topics.gdoc'
# 'Copy of JNAC Prelims 2012.doc.gdoc'
# 'Crash Lab 2.gdoc'
# 'Crash Lab.gdoc'
#  data_file_for_adam.xlsx
#  data_file_for_adam.xlsx.gsheet
# 'D&D 5e - Players Handbook (Small).pdf'
# 'Diet plan + Exercise.gdoc'
#  さるくもがっせん.docx
#  さるくもがっせん.docx.gdoc
# 'DPA Holiday Christmas Party 2019'
# 'Dropping Ball Lab.gdoc'
# 'Eat this instead:.gdoc'
#  Ellis1.docx
# 'Emotional Stuff.gdoc'
# 'EMPCA thoughts.gdoc'
# 'Enrollment Verification Form (EVF).pdf'
#  EthicsCapstone.gdoc
# 'Ethics Talk.gslides'
# 'EVF 2017.pdf'
# 'Example spectra graph.gdoc'
# 'Exam Schedule.gdoc'
# 'Exploratory Analysis of Broad Absorption Quasars.gslides'
# 'Feelings 11 11 2019.gdoc'
# 'Feelings 11 8.gdoc'
# 'Final Talk Outline.gdoc'
# 'Find a Time.gform'
#  Form1-1.docx
#  Form1-1.docx.gdoc
#  Form1-2.docx
#  Form1-2.docx.gdoc
#  Form2-1.pdf
#  Form4.pdf
#  Form4.pdf.gdoc
# 'Free Fall Lab.gdoc'
#  FullSizeRender.jpg
# 'FYRE1415 Application.pdf'
# 'GEF request for funds.docx'
# 'GEF request for funds.docx.gdoc'
# 'GEF request for funds.gdoc'
# 'GEF request for funds.pdf'
# 'Go and Measure 2.gdoc'
#  GOM_lab_handout.pdf
# 'Grad Schools.gdoc'
#  grb050525A_all.dat
#  grb050525A.txt
# 'Grocery List.gdoc'
# 'Group2--peer evaluation.gsheet'
# 'Group2--peer evaluation.xls'
#  Heisenberg_GOMLab.docx
# 'Heisenberg Lab Review.gdoc'
#  Hokkaidounoryokou.pptx
#  Homeworks.gdoc
# 'HTML Examples.gdoc'
# 'HTML Notes.gdoc'
#  Id
#  ID995A.pdf
# 'Ideal Gas Models Lab.gdoc'
# 'image1 (1).JPG'
#  image1.JPG
#  image2.JPG
#  image3.JPG
#  image4.JPG
#  image5.JPG
#  IMG_0357.MOV
#  IMG_0717.JPG
#  IMG_1393.JPG
#  IMG_7279.jpg
# 'Job Ideas.gdoc'
# 'Journal10 13.gdoc'
# 'Journal10 19.gdoc'
#  JulieExplore1.gslides
#  JuliePictureVday
#  just-for-two.pdf
#  kaggle.json
#  king_pounds.gdoc
#  king_pounds.pdf
# 'Lab 5.gdoc'
# 'Lab 6: Circuits.gdoc'
# 'Lab 7: Superconductivity.gdoc'
# 'Lab 9.gdoc'
#  Lab_Final_presentation.ppt
# 'Lab winter times.gform'
# 'Lab Winter times.gsheet'
# 'Leasing agreement  Adam.doc'
#  LIFEEEEEEE.gdoc
#  MachiavelliFinal.docx
#  MachiavelliFinal.docx.gdoc
# 'Machiavelli notes.gdoc'
#  MachineAbstract.gdoc
#  Mail_Order_Summer_Residence_2018_Double_Room.pdf
# 'March 4th.gdoc'
# 'MarrsAdam-draft (1).pptx'
#  MarrsAdam-draft.pptx
# 'Marrs Adam Transcript Yamagata SP17.pdf'
#  MarrsAdamVoterRegistration.pdf
#  MarrsAResume.gdoc
#  MarrsAResume.pdf
#  MarrsAResumeTechnical3.gdoc
#  MarrsAResumeTechnical3.pdf
#  MarrsAResumeTechnical.docx
#  MarrsComp4.doc
#  MarrsComp4.doc.gdoc
# 'Meal Prep.gdoc'
#  media_b74_b74acc51-00ef-44b5-b68b-d604941f5120_php1o92An.png
# 'Medical Information Form REV0113 (1).pdf'
# 'Medical Information Form REV0113.pdf'
#  mesa.tar.gz
#  modifiedfinalize5.pro
# 'Moment of Inertia - Excel Data Sheet (1).gsheet'
# 'Moment of Inertia - Excel Data Sheet (1).xlsx'
#  Monster.gdoc
# 'Motion and Forces Lab.gdoc'
# 'MuonDraft (1).gdoc'
# 'MuonDraft (2).gdoc'
#  MuonDraft.docx
#  MuonDraft.docx.gdoc
#  MuonDraft.gdoc
# 'My Script.gdoc'
#  NMRFinal.pdf
#  NMRFinal.pdf.gdoc
# 'NMR prelab.gslides'
# 'NMR Write Up (1).docx.gdoc'
# 'NMR Write Up.docx'
# 'NMR Write Up.docx.gdoc'
# 'PHYS 202-Lab 3.gdoc'
# 'Physics Honors.gdoc'
# 'Physics Lab 1 (8 21 14).gdoc'
# 'Physics Videos Go+Measure 2'
#  pipeline_test.html
#  Plan.gdoc
# 'Plastic Fantastic Reading Quiz.gdoc'
#  Player.gdoc
# 'Position Bounce.JPG'
# 'Post Hurrah.gdoc'
# 'Pre Lab 6. .gdoc'
# 'Pre-lab Cavendish.gslides'
# 'Presentation Notes.gdoc'
#  price-volume-data-for-all-us-stocks-etfs.zip
# 'QR Barcode'
#  Quantum.gdoc
#  QuantumResearchOutline.gdoc
#  rawG.png
#  Research.gdoc
#  ResearchProject2.pdf
#  Response.gdoc
# 'Response Paper 2.gdoc'
#  Roadtrip.gdoc
# 'Rotional and Translational Energy.gdoc'
# 'Rubric for Lab 6.docx'
# 'Rubric for Lab 6.gdoc'
# 'SA Course Equivalency Request Form.pdf'
# 'Same Mass Bounce.trk'
#  SarimaEx
# 'Satire Essay.gdoc'
# "Schindler's List.gdoc"
# 'Session 1 - Why.pub'
# 'SimPoster (1).pptx.gslides'
#  SimPoster.pptx
#  SimPoster.pptx.gslides
#  SPHS-OFF-KM13101812561.pdf
# 'Star Party.gdoc'
# 'Statistical View of Entropy.gdoc'
#  StellarFinal.gslides
#  stock_volume
#  Study_Abroad_Academic_Progress.pdf
# 'Study Abroad.gdoc'
#  TESLA
#  text_0.gdoc
# 'Things to do..gdoc'
# 'Thoughts and Things about things.gdoc'
# 'Thoughts .gdoc'
#  TicketMasquerade.pdf
# 'Together Time.gsheet'
# 'Tomorrow (1).gdoc'
#  Tomorrow.gdoc
# 'Torsional Oscillator Write Up.docx'
# 'Understanding Global.gdoc'
# 'Universe Presentation.gslides'
# 'Untitled document (10).gdoc'
# 'Untitled document (1).gdoc'
# 'Untitled document (2).gdoc'
# 'Untitled document (3).gdoc'
# 'Untitled document (4).gdoc'
# 'Untitled document (5).gdoc'
# 'Untitled document (6).gdoc'
# 'Untitled document (7).gdoc'
# 'Untitled document (8).gdoc'
# 'Untitled document (9).gdoc'
# 'Untitled document.gdoc'
# 'Untitled presentation.gslides'
# 'Varying Mass Bounce.trk'
# 'Varying Mass Stick.trk'
# 'Velocity Bounce Test.JPG'
#  Venus_Factor_Workout.pdf
#  VID_20190502_222737.mp4
# 'Voice_191129_6[1].mp3'
# 'Waiver and Release 1012 (1).pdf'
# 'Waiver and Release 1012.pdf'
#  Weekend.gdoc
#  WIN_20191022_14_17_50_Pro.mp4
#  WIN_20191024_07_31_04_Pro.mp4
# 'Work and Energy Lab.gdoc'
# '作文                                                                                                                      ~時、あまりマナーやエチケットがありません。たいてい、ここですぐにあけてもいいです。.gdoc'
# '入居許可申請書（Application From For Residence Approval）.docx'
# '入居許可申請書（Application From For Residence Approval）.docx.gdoc'
#  北海道の旅行.pdf
# '在留資格認定証明書交付申請書 Application for Certificate of Eligibility[1].gsheet'
# '在留資格認定証明書交付申請書 Application for Certificate of Eligibility (1).xls.gsheet'
# '在留資格認定証明書交付申請書 Application for Certificate of Eligibility.xls'
# '在留資格認定証明書交付申請書 Application for Certificate of Eligibility.xls.gsheet'
#  要項（英語）.pdf
# '記入例 （英語）.pdf'

# %%
#!mkdir SarimaEx

# %%
#cd SarimaEx/

# %%
#mkdir Data

# %%
#cd Data/

# %%
#!pwd

# %%
# !ls
# Out:
#  13-23-05.mp4
# '1 cm Graph.JPG'
# '1st half of Soph-Junior Questions.docx.gdoc'
#  20161017_STEPYU9.docx
#  20161017_STEPYU9.docx.gdoc
#  20170110_165644.jpg
# '2017-05-16 Transcript_INTL Evaluation_Marrs, Adam 113094771.doc'
#  20190407_205955.jpg
#  20190407_210008.jpg
#  20190407_210014.jpg
# '20191130_141319[1] (1).mp4'
# '20191130_141319[1].mp4'
# '2 25-uggs.gdoc'
# '2 cm Graph.JPG'
# '3 cm Graph.JPG'
#  ニナ　アダム　アンバー　（3）.docx
#  ニナ　アダム　アンバー　（3）.docx.gdoc
# '45 Degree Collision.trk'
# '45 Degree Stick.trk'
# '4 Cm Graph.JPG'
# '90 Degree Collision.trk'
# '90 Degree Stick.trk'
#  aas_application.pdf
#  AAsecretstratgg.docx.gdoc
#  Abstract.gdoc
#  Accomplishments.gdoc
# 'ACT 201604 Form 73E-www.crackact.com.pdf'
# 'ACT 201612 Form 74H-www.crackact.com.pdf'
# 'ACT 201706 Form 74C-www.crackact.com.pdf'
# 'Adam Marrs AP Lit Block 2'
#  AdamMarrsASTR5900Outline.gdoc
#  ADAMPLAN.docx
#  adjustG.png
#  alsdhfo.jpg
# 'Analytical Essay 2.gdoc'
# '◆Arrival Informaiton Form(Excel).xlsx'
# '◆Arrival Informaiton Form(Excel).xlsx.gsheet'
# 'Birth and Death.gdoc'
# 'Boarding Pass - Check-in | Spirit Airlines.pdf'
#  Book1.xlsx
#  Boss.gdoc
# 'Braden Nrg-time.jpg'
# 'Car totaled.gdoc'
# 'CavendishFinalDraft (1).docx1.docx.docx.gdoc'
#  CavendishFinalDraft.docx
# 'CavendishFinalDraft.docx (1).docx'
#  CavendishFinalDraft.docx1.docx.docx
#  CavendishFinalDraft.docx1.docx.docx.gdoc
# 'CavendishFinalDraft.docx (1).docx.gdoc'
#  CavendishFinalDraft.docx.gdoc
# 'Cavendish Rough Draft.gdoc'
# 'Cavendish Write Up (1).docx.gdoc'
# 'Cavendish Write Up (2).docx.gdoc'
# 'Cavendish Write Up.docx'
# 'Cavendish Write Up.docx.gdoc'
# 'cd_15_minute_talk(5).pdf'
#  Chapter10exercises.docx
#  Chapter10exercises.docx.gdoc
# 'Chapter 11 Exercises.gdoc'
# 'Chapter 9 Exercises.gdoc'
#  Characters.gdoc
#  charguide.png
# 'Chicago Trip.gdoc'
#  Circuits.gslides
# 'CityU Student Residence Application SU18.pdf'
# 'Coding Records.gdoc'
# 'Colab Notebooks'
#  Colleges.gdoc
# 'College Stuff Fall 2017.gdoc'
# 'Conversation Topics.gdoc'
# 'Copy of JNAC Prelims 2012.doc.gdoc'
# 'Crash Lab 2.gdoc'
# 'Crash Lab.gdoc'
#  data_file_for_adam.xlsx
#  data_file_for_adam.xlsx.gsheet
# 'D&D 5e - Players Handbook (Small).pdf'
# 'Diet plan + Exercise.gdoc'
#  さるくもがっせん.docx
#  さるくもがっせん.docx.gdoc
# 'DPA Holiday Christmas Party 2019'
# 'Dropping Ball Lab.gdoc'
# 'Eat this instead:.gdoc'
#  Ellis1.docx
# 'Emotional Stuff.gdoc'
# 'EMPCA thoughts.gdoc'
# 'Enrollment Verification Form (EVF).pdf'
#  EthicsCapstone.gdoc
# 'Ethics Talk.gslides'
# 'EVF 2017.pdf'
# 'Example spectra graph.gdoc'
# 'Exam Schedule.gdoc'
# 'Exploratory Analysis of Broad Absorption Quasars.gslides'
# 'Feelings 11 11 2019.gdoc'
# 'Feelings 11 8.gdoc'
# 'Final Talk Outline.gdoc'
# 'Find a Time.gform'
#  Form1-1.docx
#  Form1-1.docx.gdoc
#  Form1-2.docx
#  Form1-2.docx.gdoc
#  Form2-1.pdf
#  Form4.pdf
#  Form4.pdf.gdoc
# 'Free Fall Lab.gdoc'
#  FullSizeRender.jpg
# 'FYRE1415 Application.pdf'
# 'GEF request for funds.docx'
# 'GEF request for funds.docx.gdoc'
# 'GEF request for funds.gdoc'
# 'GEF request for funds.pdf'
# 'Go and Measure 2.gdoc'
#  GOM_lab_handout.pdf
# 'Grad Schools.gdoc'
#  grb050525A_all.dat
#  grb050525A.txt
# 'Grocery List.gdoc'
# 'Group2--peer evaluation.gsheet'
# 'Group2--peer evaluation.xls'
#  Heisenberg_GOMLab.docx
# 'Heisenberg Lab Review.gdoc'
#  Hokkaidounoryokou.pptx
#  Homeworks.gdoc
# 'HTML Examples.gdoc'
# 'HTML Notes.gdoc'
#  Id
#  ID995A.pdf
# 'Ideal Gas Models Lab.gdoc'
# 'image1 (1).JPG'
#  image1.JPG
#  image2.JPG
#  image3.JPG
#  image4.JPG
#  image5.JPG
#  IMG_0357.MOV
#  IMG_0717.JPG
#  IMG_1393.JPG
#  IMG_7279.jpg
# 'Job Ideas.gdoc'
# 'Journal10 13.gdoc'
# 'Journal10 19.gdoc'
#  JulieExplore1.gslides
#  JuliePictureVday
#  just-for-two.pdf
#  kaggle.json
#  king_pounds.gdoc
#  king_pounds.pdf
# 'Lab 5.gdoc'
# 'Lab 6: Circuits.gdoc'
# 'Lab 7: Superconductivity.gdoc'
# 'Lab 9.gdoc'
#  Lab_Final_presentation.ppt
# 'Lab winter times.gform'
# 'Lab Winter times.gsheet'
# 'Leasing agreement  Adam.doc'
#  LIFEEEEEEE.gdoc
#  MachiavelliFinal.docx
#  MachiavelliFinal.docx.gdoc
# 'Machiavelli notes.gdoc'
#  MachineAbstract.gdoc
#  Mail_Order_Summer_Residence_2018_Double_Room.pdf
# 'March 4th.gdoc'
# 'MarrsAdam-draft (1).pptx'
#  MarrsAdam-draft.pptx
# 'Marrs Adam Transcript Yamagata SP17.pdf'
#  MarrsAdamVoterRegistration.pdf
#  MarrsAResume.gdoc
#  MarrsAResume.pdf
#  MarrsAResumeTechnical3.gdoc
#  MarrsAResumeTechnical3.pdf
#  MarrsAResumeTechnical.docx
#  MarrsComp4.doc
#  MarrsComp4.doc.gdoc
# 'Meal Prep.gdoc'
#  media_b74_b74acc51-00ef-44b5-b68b-d604941f5120_php1o92An.png
# 'Medical Information Form REV0113 (1).pdf'
# 'Medical Information Form REV0113.pdf'
#  mesa.tar.gz
#  modifiedfinalize5.pro
# 'Moment of Inertia - Excel Data Sheet (1).gsheet'
# 'Moment of Inertia - Excel Data Sheet (1).xlsx'
#  Monster.gdoc
# 'Motion and Forces Lab.gdoc'
# 'MuonDraft (1).gdoc'
# 'MuonDraft (2).gdoc'
#  MuonDraft.docx
#  MuonDraft.docx.gdoc
#  MuonDraft.gdoc
# 'My Script.gdoc'
#  NMRFinal.pdf
#  NMRFinal.pdf.gdoc
# 'NMR prelab.gslides'
# 'NMR Write Up (1).docx.gdoc'
# 'NMR Write Up.docx'
# 'NMR Write Up.docx.gdoc'
# 'PHYS 202-Lab 3.gdoc'
# 'Physics Honors.gdoc'
# 'Physics Lab 1 (8 21 14).gdoc'
# 'Physics Videos Go+Measure 2'
#  pipeline_test.html
#  Plan.gdoc
# 'Plastic Fantastic Reading Quiz.gdoc'
#  Player.gdoc
# 'Position Bounce.JPG'
# 'Post Hurrah.gdoc'
# 'Pre Lab 6. .gdoc'
# 'Pre-lab Cavendish.gslides'
# 'Presentation Notes.gdoc'
#  price-volume-data-for-all-us-stocks-etfs.zip
# 'QR Barcode'
#  Quantum.gdoc
#  QuantumResearchOutline.gdoc
#  rawG.png
#  Research.gdoc
#  ResearchProject2.pdf
#  Response.gdoc
# 'Response Paper 2.gdoc'
#  Roadtrip.gdoc
# 'Rotional and Translational Energy.gdoc'
# 'Rubric for Lab 6.docx'
# 'Rubric for Lab 6.gdoc'
# 'SA Course Equivalency Request Form.pdf'
# 'Same Mass Bounce.trk'
#  SarimaEx
# 'Satire Essay.gdoc'
# "Schindler's List.gdoc"
# 'Session 1 - Why.pub'
# 'SimPoster (1).pptx.gslides'
#  SimPoster.pptx
#  SimPoster.pptx.gslides
#  SPHS-OFF-KM13101812561.pdf
# 'Star Party.gdoc'
# 'Statistical View of Entropy.gdoc'
#  StellarFinal.gslides
#  stock_volume
#  Study_Abroad_Academic_Progress.pdf
# 'Study Abroad.gdoc'
#  TESLA
#  text_0.gdoc
# 'Things to do..gdoc'
# 'Thoughts and Things about things.gdoc'
# 'Thoughts .gdoc'
#  TicketMasquerade.pdf
# 'Together Time.gsheet'
# 'Tomorrow (1).gdoc'
#  Tomorrow.gdoc
# 'Torsional Oscillator Write Up.docx'
# 'Understanding Global.gdoc'
# 'Universe Presentation.gslides'
# 'Untitled document (10).gdoc'
# 'Untitled document (1).gdoc'
# 'Untitled document (2).gdoc'
# 'Untitled document (3).gdoc'
# 'Untitled document (4).gdoc'
# 'Untitled document (5).gdoc'
# 'Untitled document (6).gdoc'
# 'Untitled document (7).gdoc'
# 'Untitled document (8).gdoc'
# 'Untitled document (9).gdoc'
# 'Untitled document.gdoc'
# 'Untitled presentation.gslides'
# 'Varying Mass Bounce.trk'
# 'Varying Mass Stick.trk'
# 'Velocity Bounce Test.JPG'
#  Venus_Factor_Workout.pdf
#  VID_20190502_222737.mp4
# 'Voice_191129_6[1].mp3'
# 'Waiver and Release 1012 (1).pdf'
# 'Waiver and Release 1012.pdf'
#  Weekend.gdoc
#  WIN_20191022_14_17_50_Pro.mp4
#  WIN_20191024_07_31_04_Pro.mp4
# 'Work and Energy Lab.gdoc'
# '作文                                                                                                                      ~時、あまりマナーやエチケットがありません。たいてい、ここですぐにあけてもいいです。.gdoc'
# '入居許可申請書（Application From For Residence Approval）.docx'
# '入居許可申請書（Application From For Residence Approval）.docx.gdoc'
#  北海道の旅行.pdf
# '在留資格認定証明書交付申請書 Application for Certificate of Eligibility[1].gsheet'
# '在留資格認定証明書交付申請書 Application for Certificate of Eligibility (1).xls.gsheet'
# '在留資格認定証明書交付申請書 Application for Certificate of Eligibility.xls'
# '在留資格認定証明書交付申請書 Application for Certificate of Eligibility.xls.gsheet'
#  要項（英語）.pdf
# '記入例 （英語）.pdf'

# %%
# !unzip price-volume-data-for-all-us-stocks-etfs.zip
# Out:
# Archive:  price-volume-data-for-all-us-stocks-etfs.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of price-volume-data-for-all-us-stocks-etfs.zip or
#         price-volume-data-for-all-us-stocks-etfs.zip.zip, and cannot find price-volume-data-for-all-us-stocks-etfs.zip.ZIP, period.

# %%
# !ls
# Out:
#  13-23-05.mp4
# '1 cm Graph.JPG'
# '1st half of Soph-Junior Questions.docx.gdoc'
#  20161017_STEPYU9.docx
#  20161017_STEPYU9.docx.gdoc
#  20170110_165644.jpg
# '2017-05-16 Transcript_INTL Evaluation_Marrs, Adam 113094771.doc'
#  20190407_205955.jpg
#  20190407_210008.jpg
#  20190407_210014.jpg
# '20191130_141319[1] (1).mp4'
# '20191130_141319[1].mp4'
# '2 25-uggs.gdoc'
# '2 cm Graph.JPG'
# '3 cm Graph.JPG'
#  ニナ　アダム　アンバー　（3）.docx
#  ニナ　アダム　アンバー　（3）.docx.gdoc
# '45 Degree Collision.trk'
# '45 Degree Stick.trk'
# '4 Cm Graph.JPG'
# '90 Degree Collision.trk'
# '90 Degree Stick.trk'
#  aas_application.pdf
#  AAsecretstratgg.docx.gdoc
#  Abstract.gdoc
#  Accomplishments.gdoc
# 'ACT 201604 Form 73E-www.crackact.com.pdf'
# 'ACT 201612 Form 74H-www.crackact.com.pdf'
# 'ACT 201706 Form 74C-www.crackact.com.pdf'
# 'Adam Marrs AP Lit Block 2'
#  AdamMarrsASTR5900Outline.gdoc
#  ADAMPLAN.docx
#  adjustG.png
#  alsdhfo.jpg
# 'Analytical Essay 2.gdoc'
# '◆Arrival Informaiton Form(Excel).xlsx'
# '◆Arrival Informaiton Form(Excel).xlsx.gsheet'
# 'Birth and Death.gdoc'
# 'Boarding Pass - Check-in | Spirit Airlines.pdf'
#  Book1.xlsx
#  Boss.gdoc
# 'Braden Nrg-time.jpg'
# 'Car totaled.gdoc'
# 'CavendishFinalDraft (1).docx1.docx.docx.gdoc'
#  CavendishFinalDraft.docx
# 'CavendishFinalDraft.docx (1).docx'
#  CavendishFinalDraft.docx1.docx.docx
#  CavendishFinalDraft.docx1.docx.docx.gdoc
# 'CavendishFinalDraft.docx (1).docx.gdoc'
#  CavendishFinalDraft.docx.gdoc
# 'Cavendish Rough Draft.gdoc'
# 'Cavendish Write Up (1).docx.gdoc'
# 'Cavendish Write Up (2).docx.gdoc'
# 'Cavendish Write Up.docx'
# 'Cavendish Write Up.docx.gdoc'
# 'cd_15_minute_talk(5).pdf'
#  Chapter10exercises.docx
#  Chapter10exercises.docx.gdoc
# 'Chapter 11 Exercises.gdoc'
# 'Chapter 9 Exercises.gdoc'
#  Characters.gdoc
#  charguide.png
# 'Chicago Trip.gdoc'
#  Circuits.gslides
# 'CityU Student Residence Application SU18.pdf'
# 'Coding Records.gdoc'
# 'Colab Notebooks'
#  Colleges.gdoc
# 'College Stuff Fall 2017.gdoc'
# 'Conversation Topics.gdoc'
# 'Copy of JNAC Prelims 2012.doc.gdoc'
# 'Crash Lab 2.gdoc'
# 'Crash Lab.gdoc'
#  data_file_for_adam.xlsx
#  data_file_for_adam.xlsx.gsheet
# 'D&D 5e - Players Handbook (Small).pdf'
# 'Diet plan + Exercise.gdoc'
#  さるくもがっせん.docx
#  さるくもがっせん.docx.gdoc
# 'DPA Holiday Christmas Party 2019'
# 'Dropping Ball Lab.gdoc'
# 'Eat this instead:.gdoc'
#  Ellis1.docx
# 'Emotional Stuff.gdoc'
# 'EMPCA thoughts.gdoc'
# 'Enrollment Verification Form (EVF).pdf'
#  EthicsCapstone.gdoc
# 'Ethics Talk.gslides'
# 'EVF 2017.pdf'
# 'Example spectra graph.gdoc'
# 'Exam Schedule.gdoc'
# 'Exploratory Analysis of Broad Absorption Quasars.gslides'
# 'Feelings 11 11 2019.gdoc'
# 'Feelings 11 8.gdoc'
# 'Final Talk Outline.gdoc'
# 'Find a Time.gform'
#  Form1-1.docx
#  Form1-1.docx.gdoc
#  Form1-2.docx
#  Form1-2.docx.gdoc
#  Form2-1.pdf
#  Form4.pdf
#  Form4.pdf.gdoc
# 'Free Fall Lab.gdoc'
#  FullSizeRender.jpg
# 'FYRE1415 Application.pdf'
# 'GEF request for funds.docx'
# 'GEF request for funds.docx.gdoc'
# 'GEF request for funds.gdoc'
# 'GEF request for funds.pdf'
# 'Go and Measure 2.gdoc'
#  GOM_lab_handout.pdf
# 'Grad Schools.gdoc'
#  grb050525A_all.dat
#  grb050525A.txt
# 'Grocery List.gdoc'
# 'Group2--peer evaluation.gsheet'
# 'Group2--peer evaluation.xls'
#  Heisenberg_GOMLab.docx
# 'Heisenberg Lab Review.gdoc'
#  Hokkaidounoryokou.pptx
#  Homeworks.gdoc
# 'HTML Examples.gdoc'
# 'HTML Notes.gdoc'
#  Id
#  ID995A.pdf
# 'Ideal Gas Models Lab.gdoc'
# 'image1 (1).JPG'
#  image1.JPG
#  image2.JPG
#  image3.JPG
#  image4.JPG
#  image5.JPG
#  IMG_0357.MOV
#  IMG_0717.JPG
#  IMG_1393.JPG
#  IMG_7279.jpg
# 'Job Ideas.gdoc'
# 'Journal10 13.gdoc'
# 'Journal10 19.gdoc'
#  JulieExplore1.gslides
#  JuliePictureVday
#  just-for-two.pdf
#  kaggle.json
#  king_pounds.gdoc
#  king_pounds.pdf
# 'Lab 5.gdoc'
# 'Lab 6: Circuits.gdoc'
# 'Lab 7: Superconductivity.gdoc'
# 'Lab 9.gdoc'
#  Lab_Final_presentation.ppt
# 'Lab winter times.gform'
# 'Lab Winter times.gsheet'
# 'Leasing agreement  Adam.doc'
#  LIFEEEEEEE.gdoc
#  MachiavelliFinal.docx
#  MachiavelliFinal.docx.gdoc
# 'Machiavelli notes.gdoc'
#  MachineAbstract.gdoc
#  Mail_Order_Summer_Residence_2018_Double_Room.pdf
# 'March 4th.gdoc'
# 'MarrsAdam-draft (1).pptx'
#  MarrsAdam-draft.pptx
# 'Marrs Adam Transcript Yamagata SP17.pdf'
#  MarrsAdamVoterRegistration.pdf
#  MarrsAResume.gdoc
#  MarrsAResume.pdf
#  MarrsAResumeTechnical3.gdoc
#  MarrsAResumeTechnical3.pdf
#  MarrsAResumeTechnical.docx
#  MarrsComp4.doc
#  MarrsComp4.doc.gdoc
# 'Meal Prep.gdoc'
#  media_b74_b74acc51-00ef-44b5-b68b-d604941f5120_php1o92An.png
# 'Medical Information Form REV0113 (1).pdf'
# 'Medical Information Form REV0113.pdf'
#  mesa.tar.gz
#  modifiedfinalize5.pro
# 'Moment of Inertia - Excel Data Sheet (1).gsheet'
# 'Moment of Inertia - Excel Data Sheet (1).xlsx'
#  Monster.gdoc
# 'Motion and Forces Lab.gdoc'
# 'MuonDraft (1).gdoc'
# 'MuonDraft (2).gdoc'
#  MuonDraft.docx
#  MuonDraft.docx.gdoc
#  MuonDraft.gdoc
# 'My Script.gdoc'
#  NMRFinal.pdf
#  NMRFinal.pdf.gdoc
# 'NMR prelab.gslides'
# 'NMR Write Up (1).docx.gdoc'
# 'NMR Write Up.docx'
# 'NMR Write Up.docx.gdoc'
# 'PHYS 202-Lab 3.gdoc'
# 'Physics Honors.gdoc'
# 'Physics Lab 1 (8 21 14).gdoc'
# 'Physics Videos Go+Measure 2'
#  pipeline_test.html
#  Plan.gdoc
# 'Plastic Fantastic Reading Quiz.gdoc'
#  Player.gdoc
# 'Position Bounce.JPG'
# 'Post Hurrah.gdoc'
# 'Pre Lab 6. .gdoc'
# 'Pre-lab Cavendish.gslides'
# 'Presentation Notes.gdoc'
#  price-volume-data-for-all-us-stocks-etfs.zip
# 'QR Barcode'
#  Quantum.gdoc
#  QuantumResearchOutline.gdoc
#  rawG.png
#  Research.gdoc
#  ResearchProject2.pdf
#  Response.gdoc
# 'Response Paper 2.gdoc'
#  Roadtrip.gdoc
# 'Rotional and Translational Energy.gdoc'
# 'Rubric for Lab 6.docx'
# 'Rubric for Lab 6.gdoc'
# 'SA Course Equivalency Request Form.pdf'
# 'Same Mass Bounce.trk'
#  SarimaEx
# 'Satire Essay.gdoc'
# "Schindler's List.gdoc"
# 'Session 1 - Why.pub'
# 'SimPoster (1).pptx.gslides'
#  SimPoster.pptx
#  SimPoster.pptx.gslides
#  SPHS-OFF-KM13101812561.pdf
# 'Star Party.gdoc'
# 'Statistical View of Entropy.gdoc'
#  StellarFinal.gslides
#  stock_volume
#  Study_Abroad_Academic_Progress.pdf
# 'Study Abroad.gdoc'
#  TESLA
#  text_0.gdoc
# 'Things to do..gdoc'
# 'Thoughts and Things about things.gdoc'
# 'Thoughts .gdoc'
#  TicketMasquerade.pdf
# 'Together Time.gsheet'
# 'Tomorrow (1).gdoc'
#  Tomorrow.gdoc
# 'Torsional Oscillator Write Up.docx'
# 'Understanding Global.gdoc'
# 'Universe Presentation.gslides'
# 'Untitled document (10).gdoc'
# 'Untitled document (1).gdoc'
# 'Untitled document (2).gdoc'
# 'Untitled document (3).gdoc'
# 'Untitled document (4).gdoc'
# 'Untitled document (5).gdoc'
# 'Untitled document (6).gdoc'
# 'Untitled document (7).gdoc'
# 'Untitled document (8).gdoc'
# 'Untitled document (9).gdoc'
# 'Untitled document.gdoc'
# 'Untitled presentation.gslides'
# 'Varying Mass Bounce.trk'
# 'Varying Mass Stick.trk'
# 'Velocity Bounce Test.JPG'
#  Venus_Factor_Workout.pdf
#  VID_20190502_222737.mp4
# 'Voice_191129_6[1].mp3'
# 'Waiver and Release 1012 (1).pdf'
# 'Waiver and Release 1012.pdf'
#  Weekend.gdoc
#  WIN_20191022_14_17_50_Pro.mp4
#  WIN_20191024_07_31_04_Pro.mp4
# 'Work and Energy Lab.gdoc'
# '作文                                                                                                                      ~時、あまりマナーやエチケットがありません。たいてい、ここですぐにあけてもいいです。.gdoc'
# '入居許可申請書（Application From For Residence Approval）.docx'
# '入居許可申請書（Application From For Residence Approval）.docx.gdoc'
#  北海道の旅行.pdf
# '在留資格認定証明書交付申請書 Application for Certificate of Eligibility[1].gsheet'
# '在留資格認定証明書交付申請書 Application for Certificate of Eligibility (1).xls.gsheet'
# '在留資格認定証明書交付申請書 Application for Certificate of Eligibility.xls'
# '在留資格認定証明書交付申請書 Application for Certificate of Eligibility.xls.gsheet'
#  要項（英語）.pdf
# '記入例 （英語）.pdf'

# %%
alltss = []

allfiles = np.sort(np.array(glob.glob("Stocks/*.txt")))[:10]
tss = pd.read_csv(allfiles[0])[["Date", "Close"]].rename({"Close":allfiles[0].replace(".txt","").replace("Stocks/", "")}, axis=1)
for f in allfiles[1:]:
    print(f)
    name = f.replace(".txt","").replace("Stocks/", "")
    
    tss = tss.merge(pd.read_csv(f)[["Date", "Close"]].rename({"Close":name}, axis=1), on="Date")
tss.set_index("Date", inplace=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-41-d57c73e28c29> in <module>()
#       3
#       4 allfiles = np.sort(np.array(glob.glob("Stocks/*.txt")))[:10]
# ----> 5 tss = pd.read_csv(allfiles[0])[["Date", "Close"]].rename({"Close":allfiles[0].replace(".txt","").replace("Stocks/", "")}, axis=1)
#       6 for f in allfiles[1:]:
#       7     print(f)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %% [markdown]
# #  data inspection
#
# plot each time series (ts)

# %%
for c in tss.columns:
    fig, ax = pl.subplots(figsize=(10,4))
    tss.plot(y=c, ax=ax, rot=75)

tss.shape

# %%
tss.index = pd.to_datetime(tss.index)#[['aame.us']]

# %%
import statsmodels.api as sm
sm.tsa.SARIMAX?

# %%
# Step 1: construct an SARIMAX model for Atlantic American Corporation data
model = sm.tsa.SARIMAX(tss[['aame.us']], order=(1, 1, 1), trend='c')

# Step 2: fit the model's parameters by maximum likelihood
results = model.fit()

# %%
# Step 3: explore / use results

# - Print a table summarizing estimation results
print(results.summary())

# - Print only the estimated parameters
print(results.params)

# - Create diagnostic figures based on standardized residuals:
#   (1) time series graph
#   (2) histogram
#   (3) Q-Q plot
#   (4) correlogram
pl.figure(figsize=(30,30))
pl.rcParams['font.size'] = 15
results.plot_diagnostics();
