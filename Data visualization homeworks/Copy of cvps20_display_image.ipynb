# %% [markdown]
# # **CVPS20 // Example: Read and Display an Image with Matplotlib**
#
# <i>September 8, 2020</i>
#
# ---

# %% [markdown]
# One of the most important skills to develop when learning to write computer code is how to quickly find solutions through search.  Working in groups, try to figure out how to do the following with `matplotlib`:
#
# 1. read the file `data/city_image.jpg` in `cvps20` into a numpy array$^{\dagger}$
# 2. display that array as an image$^{\ddagger}$
#
# Your final output should look something like the plot below.
#
# <small> $^{\dagger}$ Note, `np.load()` only works on NumPy-format files, not jpgs. </small>
#
# <small> $^{\ddagger}$ Note, `plt.plot()` only works for point data and does <u>not</u> display images. </small>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from matplotlib import pyplot as plt

# %%
import matplotlib as mpl

# %%
img1 = plt.imread('city_image.jpg')
plt.imshow(img1)
plt.show()

# %%
img1
# Out:
# array([[[ 81, 161, 196],
#         [ 87, 167, 202],
#         [ 83, 163, 198],
#         ...,
#         [199, 189, 164],
#         [199, 189, 164],
#         [199, 189, 164]],
#
#        [[ 83, 163, 196],
#         [ 89, 169, 202],
#         [ 84, 164, 197],
#         ...,
#         [201, 191, 166],
#         [200, 190, 165],
#         [200, 189, 167]],
#
#        [[ 83, 164, 194],
#         [ 89, 170, 199],
#         [ 85, 166, 195],
#         ...,
#         [201, 191, 166],
#         [201, 191, 166],
#         [201, 191, 166]],
#
#        ...,
#
#        [[116,  40,   4],
#         [109,  32,   4],
#         [108,  31,  13],
#         ...,
#         [ 64,  59,  29],
#         [ 66,  48,  26],
#         [ 44,  14,   4]],
#
#        [[116,  37,   4],
#         [118,  41,  11],
#         [104,  26,   3],
#         ...,
#         [ 66,  62,  37],
#         [ 54,  33,  16],
#         [ 41,   7,   0]],
#
#        [[104,  25,   0],
#         [123,  44,  13],
#         [ 99,  22,   0],
# ...

# %%
import numpy as np

# %%
np.shape(img1)
# Out:
# (448, 1040, 3)

# %%
from PIL import Image

im = Image.open('city_image.jpg')
im.show()

# %%
cd examples/
# Out:
# /content/drive/My Drive/cvps20/data/examples

# %%
ls
# Out:
# city_image.jpg  ml.npy
